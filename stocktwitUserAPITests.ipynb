# %%
import sys
sys.path
sys.path.append('/workspace/userLib')
#sys.path.remove('/workspace/userLib')
sys.path
import stocktwitapi

#print('did this run. yes')

# %%
import stocktwitapi
import json
# Create a Twit Streamer
twit = stocktwitapi.twitStreamer()
# this is a comment

# Pass in all parameters to query search
#raw_json = twit.get_symbol_msgs(symbol_id="DOX", since="2021-01-20", max=0, limit=50, callback=None, filter=None)

#rawDict = twit.get_symbol_msgs(symbol_id="INTC", since=0, max=0, limit=30, callback=None, filter=None)
# get results as a json in python dictionary format
rawDict = twit.get_symbol_msgs(symbol_id="rost", since=0, max=0, limit=100, callback=None, filter=None)

# Return raw json as JSON file
#return_json_file(raw_json, "../sample_json_output/get_symbol_msgs.json")
# dumps Serialize obj as a JSON formatted stream. produces str
json_formatted_str = json.dumps(rawDict, indent=2)

# load Deserialize fp (a .read()-supporting text file or binary file containing a JSON document) to a Python object (dict)
jsonObject = json.loads(json_formatted_str)#jan 26 2021 12am

# see what is going on with the key values in the dictionary
for key in rawDict:
    value = rawDict[key]
    #print("The key and value are ({}) = ({})".format(key, value))
    
# open with "w" overwrites the contents "a+" appends to contents
f = open("tech stockTwit 2016-02-1.csv", "a+",encoding='utf-8') # note: need encoding to write non ascii character
f.write('symbol' +","+'created_at'+","+'body'+","+ 'folowers'+","+'sentiment'+"\n")    
print (rawDict['symbol']['symbol'])
symbol = rawDict['symbol']['symbol']     
for message in rawDict['messages']:
        print (message.get('id'))
        createdAt = message.get('id')
        print (message.get('created_at'))
        createdAt = message.get('created_at')
        print (message.get('body'))
        body = message.get('body')
        sanitizedbody= body.replace(",", " ").replace("\n", ".")
        print (message['user']['followers'])
        followers = message['user']['followers']
        
        #print (message.get('entities'))
        #print (message.get('entities',{}).get('sentiment',{}).get('basic'))
        sentimentObj = message['entities']['sentiment']
        #print ('sentimentObj='+sentiment)
#         if sentimentObj:
#             sentiment = message['entities']['sentiment']['basic']
#         else:
#             sentiment = 'None'
        # need to catch not value for key exception because sometimes the sentiment value is null    
        try:
            sentiment = message['entities']['sentiment']['basic']
        except:
            sentiment = 'None'
        #print (message['entities']['sentiment'])
        print(sentiment)
        f.write(symbol +","+createdAt+","+sanitizedbody+","+ str(followers)+","+sentiment+"\n")
f.close()


print(json_formatted_str)

#print(raw_json)
# Out:
# url to get msgs:https://api.stocktwits.com/api/2/streams/symbol/rost.json
# ROST
# 316849199
# 2021-04-16T16:28:38Z
# Ross Stores director just disposed of 3,250 shares  http://www.conferencecalltranscripts.org/summary/?id=9270876 $ROST
# 6955
# None
# 316848061
# 2021-04-16T16:27:09Z
# Insider George Orban reports selling 3,250 shares of $ROST for a total cost of $412,879.02 https://fintel.io/n/us/rost/orban-george?utm_source=stocktwits.com&amp;utm_medium=Referral&amp;utm_campaign=insider
# 3426
# None
# 316847674
# 2021-04-16T16:26:38Z
# $ROST [15s. delayed] filed SEC form 4: Director ORBAN GEORGE:
# Disposed 3,250 of Common Stock at price $127.04 on 2021-04-14, decreased ho https://s.flashalert.me/agr5xk
# 3540
# None
# 316847577
# 2021-04-16T16:26:30Z
# $ROST 📜 SEC Form 4: ORBAN GEORGE sold $412,879 worth of Common Stock (3,250 units at $127.04), decreasing direct ownership by 0.81% to 398,950 units
#
# https://quantisnow.com/insight/624786?s=s
#
# #consumerservices
# 916
# None
# 316847456
# 2021-04-16T16:26:22Z
# $ROST $412,880.00 of shares sold by Orban George (Director), reported in a new form 4 filed with the SEC
#
# https://newsfilter.io/a/cdfd0444b1f2b5f19c482161ce42dcf2
# 10907
# None
# 316510432
# 2021-04-16T01:46:25Z
# $HRVSF $ROST $SBUX $TPR $TGT
#
# Cannabis.
# 11
# Bullish
# 316362628
# 2021-04-15T20:18:00Z
# $ROST
# Target Raised by Loop Capital Buy USD 130 » USD 145
# https://www.stocktargetadvisor.com/stock/USA/NSD/ROST#analyst-rating-tab
# 516
# None
# 316347381
# 2021-04-15T20:00:02Z
# Large Print $ROST Size: 212978 Price: 129.07 Time: 1600 Amount: $27,489,070.46
# 6888
# None
# 316199064
# 2021-04-15T16:41:42Z
# @StocksBecomeThings This kitty in at 9 cents --- 9 lives for sure --- may die, bounce, live, and get a bit of mange --- but so much fun being a kitty in the game. Hehehe   Kitty claws are holding tight $GBOX $BYRN $NNN $ROST $AAPL
# 1
# Bullish
# 316120569
# 2021-04-15T15:01:51Z
# $ROST Loop Capital Maintains to Buy : PT $145.00 https://stockhoot.com/ExtSymbol.aspx?from=AnalystRatingTweet&amp;symbol=ROST&amp;t=983&amp;Social=StockTwits
# 2195
# None
# 316118537
# 2021-04-15T14:59:07Z
# $ROST (Ross Stores): Loop Capital Maintains  Buy &#39;Raises&#39; Price Target $130 --&gt; 145
# 749
# None
# 316118014
# 2021-04-15T14:58:29Z
# $ROST 📡 Loop Capital reiterated coverage on Ross Stores with a new price target
#
# https://quantisnow.com/insight/621028?s=s
#
# #consumerservices
# 916
# None
# 316118004
# 2021-04-15T14:58:28Z
# $ROST Loop Capital analyst Laura Champine maintains Ross Stores with a Buy and raises the price target from $130 to $145.
# 10908
# None
# 316113507
# 2021-04-15T14:52:39Z
# Bottom line is $ROST relative strength vs $TJX. And that&#39;s why I chose $ROST who is outperforming on this breakout 👍
# 179
# None
# 316103479
# 2021-04-15T14:40:04Z
# 52-Week High Alert: Trading today&#39;s movement in ROSS STORES $ROST https://wp.me/p5bLGB-cP8L
# 43099
# None
# 316062578
# 2021-04-15T13:51:20Z
# Ross Stores&#39;s PT raised by Loop Capital to $145.00. buy rating. https://www.marketbeat.com/r/1578829 $ROST
# 10074
# None
# 316023454
# 2021-04-15T12:47:21Z
# Apparel sales take off as American get ready to go back out  $TJX $ROST $LB $GPS $AEO
#
# https://newsfilter.io/a/376611f145ac87fa2b5a0cd42ffd759e
# 10907
# None
# 315980166
# 2021-04-15T09:51:00Z
# $ROST are the top gainers in the Nasdaq 100 for the day. https://www.chartmill.com/stock/stock-screener?v=3&amp;f=ind_20&amp;s=pt&amp;utm_source=stocktwits&amp;utm_medium=screener&amp;utm_content=Stock_Screener:_top_Nasdaq_100_gainers&amp;utm_campaign=social_tracking
# 27870
# None
# 315775652
# 2021-04-14T20:00:03Z
# Large Print $ROST Size: 360783 Price: 126.87 Time: 1600 Amount: $45,772,539.21
# 6888
# None
# 315478805
# 2021-04-14T12:49:29Z
# $ROST Down 3 days in a row. 128.22 | 128 | 126.39 | 120.66 |  https://www.sleekoptions.com/sleekscan.aspx?sub1=dscan
# 2670
# None
# 315213390
# 2021-04-13T20:00:01Z
# Large Print $ROST Size: 201118 Price: 126.39 Time: 1600 Amount: $25,419,304.02
# 6888
# None
# 315191566
# 2021-04-13T19:27:31Z
# $ROST short float down 0.61% from 1.58% to 0.97%
# 1361
# None
# 315077868
# 2021-04-13T16:28:04Z
# $ROST MOST RECENT TWEETS Trend/Searches/ranked 1M% Change 33 % https://t8sk.com/ROST
# 26
# Bullish
# 314731368
# 2021-04-12T21:00:25Z
# Insider Morrow Brian R. reports selling 1,462 shares of $ROST for a total cost of $186,083.36 https://fintel.io/n/us/rost/morrow-brian?utm_source=stocktwits.com&amp;utm_medium=Referral&amp;utm_campaign=insider
# 3420
# None
# 314698441
# 2021-04-12T20:00:02Z
# Large Print $ROST Size: 129282 Price: 128 Time: 1600 Amount: $16,548,096.00
# 6888
# None
# 314681882
# 2021-04-12T19:33:52Z
# $ROST institutional ownership down 0.1% from 88% to 87.9%
# 1361
# None
# 314653152
# 2021-04-12T18:44:42Z
# Ross Stores CMO Brian R. Morrow Sells $186,083.36 in $ROST https://www.marketbeat.com/i/440325
# 3638
# None
# 314568549
# 2021-04-12T16:14:11Z
# Ross Stores just filed its Statement of changes in beneficial owner http://www.conferencecalltranscripts.org/include?location=http://www.sec.gov/Archives/edgar/data/745732/000117911021004370/0001179110-21-004370-index.htm $ROST
# 6955
# None
# 314568453
# 2021-04-12T16:14:00Z
# $ROST $186,083.36 of shares sold by Morrow Brian R. (President, CMO dd&#39;s DISCOUNTS), reported in a new form 4 filed with the SEC  https://newsfilter.io/a/8b8fdd495220814e08b4d82243edc22c
# 10907
# None
# 314565789
# 2021-04-12T16:09:19Z
# $ROST [15s. delayed] filed SEC form 4: President, CMO dd&#39;s DISCOUNTS Morrow Brian R.:
# Disposed 1,462 of Common Stock at price $127.28 on  https://s.flashalert.me/idk0WL
# 3540
# None
# {
#   "response": {
#     "status": 200
#   },
#   "symbol": {
#     "id": 3413,
#     "symbol": "ROST",
#     "title": "Ross Stores Inc.",
#     "aliases": [],
#     "is_following": false,
#     "watchlist_count": 3276
#   },
#   "cursor": {
#     "more": true,
#     "since": 316849199,
#     "max": 314565789
#   },
#   "messages": [
#     {
#       "id": 316849199,
#       "body": "Ross Stores director just disposed of 3,250 shares  http://www.conferencecalltranscripts.org/summary/?id=9270876 $ROST",
#       "created_at": "2021-04-16T16:28:38Z",
#       "user": {
#         "id": 210967,
#         "username": "cctranscripts",
#         "name": "Conference Call Transcripts",
#         "avatar_url": "https://avatars.stocktwits.com/production/210967/thumb-1363372333.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/210967/thumb-1363372333.png",
#         "join_date": "2013-01-30",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 6955,
#         "following": 10,
#         "ideas": 2580710,
#         "watchlist_stocks_count": 0,
#         "like_count": 765,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1130,
#         "title": "cctranscripts",
#         "url": "http://conferencecalltranscripts.org"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "Conference Call Transcripts",
#           "url": "http://www.conferencecalltranscripts.org/summary/?id=9270876",
#           "shortened_url": "http://www.conferencecalltranscripts.org/summary/?id=9270876",
#           "shortened_expanded_url": "conferencecalltranscripts.o...",
#           "description": "Get notified next time ROST.US makes a similar move! George Orban, a director of Ross Stores, recently disposed of 3,250 shares of the company. The disposals took place at $127.04 per share, on April 14, 2021. Orban still owns 5,592,557 shares of the company. Orban operates out of Dublin, CA.",
#           "image": null,
#           "created_at": "2021-04-16T16:28:44Z",
#           "video_url": null,
#           "source": {
#             "name": "Conferencecalltranscripts",
#             "website": "http://www.conferencecalltranscripts.org"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316848061,
#       "body": "Insider George Orban reports selling 3,250 shares of $ROST for a total cost of $412,879.02 https://fintel.io/n/us/rost/orban-george?utm_source=stocktwits.com&amp;utm_medium=Referral&amp;utm_campaign=insider",
#       "created_at": "2021-04-16T16:27:09Z",
#       "user": {
#         "id": 127776,
#         "username": "risenhoover",
#         "name": "Wilton",
#         "avatar_url": "https://avatars.stocktwits.com/production/127776/thumb-1384448707.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/127776/thumb-1384448707.png",
#         "join_date": "2012-01-05",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 3426,
#         "following": 27,
#         "ideas": 565464,
#         "watchlist_stocks_count": 1,
#         "like_count": 1080,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2883,
#         "title": "Fintel.io",
#         "url": "https://fintel.io"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": null,
#           "url": "https://fintel.io/n/us/rost/orban-george?utm_source=stocktwits.com&utm_medium=Referral&utm_campaign=insider",
#           "shortened_url": "https://fintel.io/n/us/rost/orban-george?utm_source=stocktwits.com&utm_medium=Referral&utm_campaign=insider",
#           "shortened_expanded_url": "fintel.io/n/us/rost/orban-g...",
#           "description": null,
#           "image": null,
#           "created_at": "2021-04-16T16:27:09Z",
#           "video_url": null,
#           "source": {
#             "name": "Fintel",
#             "website": "https://fintel.io"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316847674,
#       "body": "$ROST [15s. delayed] filed SEC form 4: Director ORBAN GEORGE: \nDisposed 3,250 of Common Stock at price $127.04 on 2021-04-14, decreased ho https://s.flashalert.me/agr5xk",
#       "created_at": "2021-04-16T16:26:38Z",
#       "user": {
#         "id": 595702,
#         "username": "fla",
#         "name": "FlashAlert_me",
#         "avatar_url": "https://avatars.stocktwits.com/production/595702/thumb-1550769466.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/595702/thumb-1550769466.png",
#         "join_date": "2015-09-09",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 3540,
#         "following": 60,
#         "ideas": 1002727,
#         "watchlist_stocks_count": 1,
#         "like_count": 4,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 4622,
#         "title": "FlashAlert",
#         "url": "https://flashalert.me/"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": null,
#           "url": "https://s.flashalert.me/agr5xk",
#           "shortened_url": "http://s.flashalert.me/agr5xk",
#           "shortened_expanded_url": "s.flashalert.me/agr5xk",
#           "description": null,
#           "image": null,
#           "created_at": "2021-04-16T16:26:38Z",
#           "video_url": null,
#           "source": {
#             "name": "Flashalert",
#             "website": "http://s.flashalert.me"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316847577,
#       "body": "$ROST \ud83d\udcdc SEC Form 4: ORBAN GEORGE sold $412,879 worth of Common Stock (3,250 units at $127.04), decreasing direct ownership by 0.81% to 398,950 units\n\nhttps://quantisnow.com/insight/624786?s=s\n\n#consumerservices",
#       "created_at": "2021-04-16T16:26:30Z",
#       "user": {
#         "id": 4280914,
#         "username": "Quantisnow",
#         "name": "Quantisnow",
#         "avatar_url": "https://avatars.stocktwits.com/production/4280914/thumb-1604765185.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4280914/thumb-1604765185.png",
#         "join_date": "2020-11-07",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 916,
#         "following": 1,
#         "ideas": 208686,
#         "watchlist_stocks_count": 0,
#         "like_count": 214,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 5981,
#         "title": "Quantisnow",
#         "url": "https://quantisnow.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "Quantisnow",
#           "url": "https://quantisnow.com/insight/624786?s=s",
#           "shortened_url": "https://quantisnow.com/insight/624786?s=s",
#           "shortened_expanded_url": "quantisnow.com/insight/6247...",
#           "description": "Fastest customizable news feed in the world. Follow your favorite companies, SPACs or topics and get alerted as soon as material information break out. SEC filings | FDA approvals | Press releases | Insider trading | Government contracts",
#           "image": "https://quantisnow-res.s3-us-west-2.amazonaws.com/quantisnow_feature_graphic.png",
#           "created_at": "2021-04-16T16:26:31Z",
#           "video_url": null,
#           "source": {
#             "name": "Quantisnow",
#             "website": "https://quantisnow.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316847456,
#       "body": "$ROST $412,880.00 of shares sold by Orban George (Director), reported in a new form 4 filed with the SEC  \n\nhttps://newsfilter.io/a/cdfd0444b1f2b5f19c482161ce42dcf2",
#       "created_at": "2021-04-16T16:26:22Z",
#       "user": {
#         "id": 2762379,
#         "username": "Newsfilter",
#         "name": "@newsfilterio",
#         "avatar_url": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "join_date": "2019-09-01",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 10907,
#         "following": 18,
#         "ideas": 911976,
#         "watchlist_stocks_count": 1,
#         "like_count": 531,
#         "plus_tier": "month",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "4 Form - Statement of changes in beneficial ownership of securities - ROSS STORES, INC. (0000745732) (Issuer)",
#           "url": "https://newsfilter.io/a/cdfd0444b1f2b5f19c482161ce42dcf2",
#           "shortened_url": "https://newsfilter.io/a/cdfd0444b1f2b5f19c482161ce42dcf2",
#           "shortened_expanded_url": "newsfilter.io/a/cdfd0444b1f...",
#           "description": "SEC FORM 4 SEC Form 4 Check this box if no longer subject to Section 16. Form 4 or Form 5 obligations may continue. See Instruction 1(b). Table I - Non-Derivative Securities Acquired, Disposed of, or Beneficially Owned 1. Title of Security (Instr. 3) 2. Transaction Date (Month/Day/Year) 2A.",
#           "image": null,
#           "created_at": "2021-04-16T16:26:24Z",
#           "video_url": null,
#           "source": {
#             "name": "Newsfilter",
#             "website": "https://newsfilter.io"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316510432,
#       "body": "$HRVSF $ROST $SBUX $TPR $TGT  \n \nCannabis.",
#       "created_at": "2021-04-16T01:46:25Z",
#       "user": {
#         "id": 5170085,
#         "username": "15YearWeedSmoker",
#         "name": "Even",
#         "avatar_url": "https://avatars.stocktwits.com/production/5170085/thumb-1616458223.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/5170085/thumb-1616458223.png",
#         "join_date": "2021-03-02",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 11,
#         "following": 7,
#         "ideas": 468,
#         "watchlist_stocks_count": 68,
#         "like_count": 133,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         },
#         {
#           "id": 3465,
#           "symbol": "SBUX",
#           "title": "Starbucks Corporation",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 88164
#         },
#         {
#           "id": 4796,
#           "symbol": "TPR",
#           "title": "Tapestry Inc.",
#           "aliases": [
#             "COH"
#           ],
#           "is_following": false,
#           "watchlist_count": 4172
#         },
#         {
#           "id": 7396,
#           "symbol": "TGT",
#           "title": "Target Corp.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 29750
#         },
#         {
#           "id": 16072,
#           "symbol": "HRVSF",
#           "title": "Harvest Health & Recreation Inc",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 1341
#         }
#       ],
#       "likes": {
#         "total": 1,
#         "user_ids": [
#           5207253
#         ]
#       },
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": {
#           "basic": "Bullish"
#         }
#       }
#     },
#     {
#       "id": 316362628,
#       "body": "$ROST \nTarget Raised by Loop Capital Buy USD 130 \u00bb USD 145\nhttps://www.stocktargetadvisor.com/stock/USA/NSD/ROST#analyst-rating-tab",
#       "created_at": "2021-04-15T20:18:00Z",
#       "user": {
#         "id": 464077,
#         "username": "stocktargetadvisors",
#         "name": "StockTargetAdvisor",
#         "avatar_url": "https://avatars.stocktwits.com/production/464077/thumb-1572487666.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/464077/thumb-1572487666.png",
#         "join_date": "2015-02-11",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 516,
#         "following": 55,
#         "ideas": 10906,
#         "watchlist_stocks_count": 0,
#         "like_count": 1,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "links": [
#         {
#           "title": "ROST Stock Price, Financials & News | Stock Target Advisor",
#           "url": "https://www.stocktargetadvisor.com/stock/USA/NSD/ROST#analyst-rating-tab",
#           "shortened_url": "https://www.stocktargetadvisor.com/stock/USA/NSD/ROST",
#           "shortened_expanded_url": "stocktargetadvisor.com/stoc...",
#           "description": "About Ross Stores, Inc., together with its subsidiaries, operates off-price retail apparel and home fashion stores under the Ross Dress for Less and dd's DISCOUNTS brands. Its stores primarily offer apparel, accessories, footwear, and home fashions.",
#           "image": "https://www.stocktargetadvisor.com/uploads/logos/ROST.png",
#           "created_at": "2021-04-15T20:18:02Z",
#           "video_url": null,
#           "source": {
#             "name": "Stocktargetadvisor",
#             "website": "https://www.stocktargetadvisor.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316347381,
#       "body": "Large Print $ROST Size: 212978 Price: 129.07 Time: 1600 Amount: $27,489,070.46",
#       "created_at": "2021-04-15T20:00:02Z",
#       "user": {
#         "id": 4441233,
#         "username": "TradeWithAlerts",
#         "name": "TradeWithAlerts",
#         "avatar_url": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "join_date": "2020-12-17",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 6888,
#         "following": 0,
#         "ideas": 155937,
#         "watchlist_stocks_count": 22,
#         "like_count": 184,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 6081,
#         "title": "TradeWithAI",
#         "url": "https://fotodesigners.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316199064,
#       "body": "@StocksBecomeThings This kitty in at 9 cents --- 9 lives for sure --- may die, bounce, live, and get a bit of mange --- but so much fun being a kitty in the game. Hehehe   Kitty claws are holding tight $GBOX $BYRN $NNN $ROST $AAPL",
#       "created_at": "2021-04-15T16:41:42Z",
#       "user": {
#         "id": 3638164,
#         "username": "gadiffen",
#         "name": "Gail Diffendorfer",
#         "avatar_url": "https://avatars.stocktwits.com/production/3638164/thumb-1613101130.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/3638164/thumb-1613101130.png",
#         "join_date": "2020-06-16",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 1,
#         "following": 22,
#         "ideas": 120,
#         "watchlist_stocks_count": 37,
#         "like_count": 110,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 686,
#           "symbol": "AAPL",
#           "title": "Apple Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 682154
#         },
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         },
#         {
#           "id": 6525,
#           "symbol": "NNN",
#           "title": "National Retail Properties, Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 767
#         },
#         {
#           "id": 16171,
#           "symbol": "BYRN",
#           "title": "Byrna Technologies Inc",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 354
#         },
#         {
#           "id": 17390,
#           "symbol": "GBOX",
#           "title": "Greenbox Pos",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 2156
#         }
#       ],
#       "conversation": {
#         "parent_message_id": 316114855,
#         "in_reply_to_message_id": 316114855,
#         "parent": false,
#         "replies": 1
#       },
#       "mentioned_users": [
#         "@StocksBecomeThings"
#       ],
#       "entities": {
#         "sentiment": {
#           "basic": "Bullish"
#         }
#       }
#     },
#     {
#       "id": 316120569,
#       "body": "$ROST Loop Capital Maintains to Buy : PT $145.00 https://stockhoot.com/ExtSymbol.aspx?from=AnalystRatingTweet&amp;symbol=ROST&amp;t=983&amp;Social=StockTwits",
#       "created_at": "2021-04-15T15:01:51Z",
#       "user": {
#         "id": 835250,
#         "username": "Stockhoot",
#         "name": "Stockhoot",
#         "avatar_url": "https://avatars.stocktwits.com/production/835250/thumb-1510088734.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/835250/thumb-1510088734.png",
#         "join_date": "2016-09-06",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 2195,
#         "following": 103,
#         "ideas": 81797,
#         "watchlist_stocks_count": 8,
#         "like_count": 34,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 3360,
#         "title": "StockHoot",
#         "url": "https://stockhoot.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "ROST - Ross Stores Charts, Trade Ideas, Earnings, Ratings",
#           "url": "https://stockhoot.com/ExtSymbol.aspx?from=AnalystRatingTweet&symbol=ROST&t=983&Social=StockTwits",
#           "shortened_url": "https://stockhoot.com/ExtSymbol.aspx?from=AnalystRatingTweet&symbol=ROST&t=983&Social=StockTwits",
#           "shortened_expanded_url": "stockhoot.com/ExtSymbol.asp...",
#           "description": "ROST : Get atock charts, earnings, analyst ratings and investment stock tips from independent traders who track ROST. Follow their trades and see their performance",
#           "image": "https://storage.googleapis.com/iex/api/logos/ROST.png",
#           "created_at": "2021-04-15T15:01:52Z",
#           "video_url": null,
#           "source": {
#             "name": "Stockhoot",
#             "website": "https://stockhoot.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316118537,
#       "body": "$ROST (Ross Stores): Loop Capital Maintains  Buy &#39;Raises&#39; Price Target $130 --&gt; 145",
#       "created_at": "2021-04-15T14:59:07Z",
#       "user": {
#         "id": 1471971,
#         "username": "JarvisAlerts",
#         "name": "Jarvis Alerts",
#         "avatar_url": "https://avatars.stocktwits.com/production/1471971/thumb-1616611512.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/1471971/thumb-1616611512.png",
#         "join_date": "2018-04-15",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 749,
#         "following": 0,
#         "ideas": 4774,
#         "watchlist_stocks_count": 105,
#         "like_count": 371,
#         "plus_tier": "month",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 5141,
#         "title": "TestApplication",
#         "url": "http://localhost.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "chart": {
#           "thumb": "https://charts.stocktwits.com/production/small_316118537.",
#           "large": "https://charts.stocktwits.com/production/large_316118537.",
#           "original": "https://charts.stocktwits.com/production/original_316118537.",
#           "url": "https://charts.stocktwits.com/production/original_316118537."
#         },
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316118014,
#       "body": "$ROST \ud83d\udce1 Loop Capital reiterated coverage on Ross Stores with a new price target\n\nhttps://quantisnow.com/insight/621028?s=s\n\n#consumerservices",
#       "created_at": "2021-04-15T14:58:29Z",
#       "user": {
#         "id": 4280914,
#         "username": "Quantisnow",
#         "name": "Quantisnow",
#         "avatar_url": "https://avatars.stocktwits.com/production/4280914/thumb-1604765185.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4280914/thumb-1604765185.png",
#         "join_date": "2020-11-07",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 916,
#         "following": 1,
#         "ideas": 208470,
#         "watchlist_stocks_count": 0,
#         "like_count": 214,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 5981,
#         "title": "Quantisnow",
#         "url": "https://quantisnow.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "Quantisnow",
#           "url": "https://quantisnow.com/insight/621028?s=s",
#           "shortened_url": "https://quantisnow.com/insight/621028?s=s",
#           "shortened_expanded_url": "quantisnow.com/insight/6210...",
#           "description": "Fastest customizable news feed in the world. Follow your favorite companies, SPACs or topics and get alerted as soon as material information break out. SEC filings | FDA approvals | Press releases | Insider trading | Government contracts",
#           "image": "https://quantisnow-res.s3-us-west-2.amazonaws.com/quantisnow_feature_graphic.png",
#           "created_at": "2021-04-15T14:58:29Z",
#           "video_url": null,
#           "source": {
#             "name": "Quantisnow",
#             "website": "https://quantisnow.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316118004,
#       "body": "$ROST Loop Capital analyst Laura Champine maintains Ross Stores with a Buy and raises the price target from $130 to $145.",
#       "created_at": "2021-04-15T14:58:28Z",
#       "user": {
#         "id": 2762379,
#         "username": "Newsfilter",
#         "name": "@newsfilterio",
#         "avatar_url": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "join_date": "2019-09-01",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 10908,
#         "following": 18,
#         "ideas": 911801,
#         "watchlist_stocks_count": 1,
#         "like_count": 531,
#         "plus_tier": "month",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316113507,
#       "body": "Bottom line is $ROST relative strength vs $TJX. And that&#39;s why I chose $ROST who is outperforming on this breakout \ud83d\udc4d",
#       "created_at": "2021-04-15T14:52:39Z",
#       "user": {
#         "id": 1180488,
#         "username": "Fox_Technicals",
#         "name": "\ud83e\udd8a\ud83d\ude80\ud83d\udcc8",
#         "avatar_url": "https://avatars.stocktwits.com/production/1180488/thumb-1511457844.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/1180488/thumb-1511457844.png",
#         "join_date": "2017-09-06",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 179,
#         "following": 13,
#         "ideas": 4733,
#         "watchlist_stocks_count": 0,
#         "like_count": 465,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         },
#         {
#           "id": 7413,
#           "symbol": "TJX",
#           "title": "The TJX Companies, Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 5708
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "chart": {
#           "thumb": "https://charts.stocktwits.com/production/small_316113507.png",
#           "large": "https://charts.stocktwits.com/production/large_316113507.png",
#           "original": "https://charts.stocktwits.com/production/original_316113507.png",
#           "url": "https://charts.stocktwits.com/production/original_316113507.png"
#         },
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316103479,
#       "body": "52-Week High Alert: Trading today&#39;s movement in ROSS STORES $ROST https://wp.me/p5bLGB-cP8L",
#       "created_at": "2021-04-15T14:40:04Z",
#       "user": {
#         "id": 403382,
#         "username": "quantcha",
#         "name": "Quantcha",
#         "avatar_url": "https://avatars.stocktwits.com/production/403382/thumb-1411503795.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/403382/thumb-1411503795.png",
#         "join_date": "2014-09-23",
#         "official": true,
#         "identity": "Official",
#         "classification": [
#           "official"
#         ],
#         "followers": 43099,
#         "following": 34,
#         "ideas": 78750,
#         "watchlist_stocks_count": 0,
#         "like_count": 13,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1788,
#         "title": "Quantcha Ideas",
#         "url": "http://ideas.quantcha.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "52-Week High Alert: Trading today's movement in ROSS STORES $ROST",
#           "url": "https://wp.me/p5bLGB-cP8L",
#           "shortened_url": "https://ideas.quantcha.com/2021/04/15/52-week-high-alert-trading-todays-movement-in-ross-stores-rost-2/",
#           "shortened_expanded_url": "ideas.quantcha.com/2021/04/...",
#           "description": "Quantcha now offering unlimited commission-free options trading. Quantchabot has detected a promising Bull Put Spread trade opportunity for ROSS STORES ( ROST) for the 21-May-2021 expiration period. You can analyze the opportunity in depth over at the Quantcha Options Search Engine. ROST was recently trading at $129.19 and has an implied volatility of 30.68% for this period.",
#           "image": "https://i0.wp.com/ideas.quantcha.com/wp-content/uploads/2021/04/automated-805.png?fit=1200%2C630&ssl=1",
#           "created_at": "2021-04-15T14:40:14Z",
#           "video_url": null,
#           "source": {
#             "name": "Quantcha Trade Ideas",
#             "website": "https://ideas.quantcha.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "chart": {
#           "thumb": "https://charts.stocktwits.com/production/small_316103479.",
#           "large": "https://charts.stocktwits.com/production/large_316103479.",
#           "original": "https://charts.stocktwits.com/production/original_316103479.",
#           "url": "https://charts.stocktwits.com/production/original_316103479."
#         },
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316062578,
#       "body": "Ross Stores&#39;s PT raised by Loop Capital to $145.00. buy rating. https://www.marketbeat.com/r/1578829 $ROST",
#       "created_at": "2021-04-15T13:51:20Z",
#       "user": {
#         "id": 284225,
#         "username": "MarketBeat",
#         "name": "MarketBeat.com",
#         "avatar_url": "https://avatars.stocktwits.com/production/284225/thumb-1607009746.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/284225/thumb-1607009746.png",
#         "join_date": "2013-11-24",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 10074,
#         "following": 8,
#         "ideas": 960052,
#         "watchlist_stocks_count": 0,
#         "like_count": 9,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1022,
#         "title": "Zapier",
#         "url": "https://zapier.com/"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3275
#         }
#       ],
#       "links": [
#         {
#           "title": "ROST Stock Forecast, Price & News (Ross Stores)",
#           "url": "https://www.marketbeat.com/r/1578829",
#           "shortened_url": "https://www.marketbeat.com/stocks/NASDAQ/ROST/",
#           "shortened_expanded_url": "marketbeat.com/stocks/NASDA...",
#           "description": "Analyzing Ross Stores (NASDAQ:ROST) stock? View ROST's stock price, price target, dividend, earnings, financials, forecast, insider trades, news, and SEC filings at MarketBeat.",
#           "image": "https://www.marketbeat.com/logos/ross-stores-inc-logo.jpg",
#           "created_at": "2021-04-15T13:51:22Z",
#           "video_url": null,
#           "source": {
#             "name": "Marketbeat",
#             "website": "https://www.marketbeat.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 316023454,
#       "body": "Apparel sales take off as American get ready to go back out  $TJX $ROST $LB $GPS $AEO \n\nhttps://newsfilter.io/a/376611f145ac87fa2b5a0cd42ffd759e",
#       "created_at": "2021-04-15T12:47:21Z",
#       "user": {
#         "id": 2762379,
#         "username": "Newsfilter",
#         "name": "@newsfilterio",
#         "avatar_url": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "join_date": "2019-09-01",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 10907,
#         "following": 18,
#         "ideas": 911468,
#         "watchlist_stocks_count": 1,
#         "like_count": 531,
#         "plus_tier": "month",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3275
#         },
#         {
#           "id": 4255,
#           "symbol": "AEO",
#           "title": "American Eagle Outfitters, Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3914
#         },
#         {
#           "id": 5576,
#           "symbol": "GPS",
#           "title": "Gap Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 8914
#         },
#         {
#           "id": 6209,
#           "symbol": "LB",
#           "title": "L Brands, Inc. ",
#           "aliases": [
#             "LTD"
#           ],
#           "is_following": false,
#           "watchlist_count": 6593
#         },
#         {
#           "id": 7413,
#           "symbol": "TJX",
#           "title": "The TJX Companies, Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 5707
#         }
#       ],
#       "links": [
#         {
#           "title": "Apparel sales take off as American get ready to go back out",
#           "url": "https://newsfilter.io/a/376611f145ac87fa2b5a0cd42ffd759e",
#           "shortened_url": "http://newsfilter.io/a/376611f145ac87fa2b5a0cd42ffd759e",
#           "shortened_expanded_url": "newsfilter.io/a/376611f145a...",
#           "description": "Apparel sales take off as American get ready to go back out: The retail sales report for March showed a significant increase in sales of clothes and clothing accessories. The category saw a 18.3% jump..",
#           "image": null,
#           "created_at": "2021-04-15T12:47:21Z",
#           "video_url": null,
#           "source": {
#             "name": "Newsfilter",
#             "website": "http://newsfilter.io"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 315980166,
#       "body": "$ROST are the top gainers in the Nasdaq 100 for the day. https://www.chartmill.com/stock/stock-screener?v=3&amp;f=ind_20&amp;s=pt&amp;utm_source=stocktwits&amp;utm_medium=screener&amp;utm_content=Stock_Screener:_top_Nasdaq_100_gainers&amp;utm_campaign=social_tracking",
#       "created_at": "2021-04-15T09:51:00Z",
#       "user": {
#         "id": 47688,
#         "username": "ChartMill",
#         "name": "ChartMill",
#         "avatar_url": "https://avatars.stocktwits.com/production/47688/thumb-1363343728.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/47688/thumb-1363343728.png",
#         "join_date": "2011-01-26",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 27870,
#         "following": 887,
#         "ideas": 1287781,
#         "watchlist_stocks_count": 20,
#         "like_count": 32,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1135,
#         "title": "ChartMill",
#         "url": "http://www.chartmill.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "links": [
#         {
#           "title": null,
#           "url": "https://www.chartmill.com/stock/stock-screener?v=3&f=ind_20&s=pt&utm_source=stocktwits&utm_medium=screener&utm_content=Stock_Screener:_top_Nasdaq_100_gainers&utm_campaign=social_tracking",
#           "shortened_url": "https://www.chartmill.com/stock/stock-screener?v=3&f=ind_20&s=pt&utm_source=stocktwits&utm_medium=screener&utm_content=Stock_Screener:_top_Nasdaq_100_gainers&utm_campaign=social_tracking",
#           "shortened_expanded_url": "chartmill.com/stock/stock-s...",
#           "description": null,
#           "image": null,
#           "created_at": "2021-04-15T09:51:00Z",
#           "video_url": null,
#           "source": {
#             "name": "Chartmill",
#             "website": "https://www.chartmill.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 315775652,
#       "body": "Large Print $ROST Size: 360783 Price: 126.87 Time: 1600 Amount: $45,772,539.21",
#       "created_at": "2021-04-14T20:00:03Z",
#       "user": {
#         "id": 4441233,
#         "username": "TradeWithAlerts",
#         "name": "TradeWithAlerts",
#         "avatar_url": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "join_date": "2020-12-17",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 6888,
#         "following": 0,
#         "ideas": 155937,
#         "watchlist_stocks_count": 22,
#         "like_count": 184,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 6081,
#         "title": "TradeWithAI",
#         "url": "https://fotodesigners.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 315478805,
#       "body": "$ROST Down 3 days in a row. 128.22 | 128 | 126.39 | 120.66 |  https://www.sleekoptions.com/sleekscan.aspx?sub1=dscan",
#       "created_at": "2021-04-14T12:49:29Z",
#       "user": {
#         "id": 1553598,
#         "username": "sleekoptions_twits",
#         "name": "sleekOptions Signals",
#         "avatar_url": "https://avatars.stocktwits.com/production/1553598/thumb-1600048561.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/1553598/thumb-1600048561.png",
#         "join_date": "2018-07-22",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 2670,
#         "following": 48,
#         "ideas": 49360,
#         "watchlist_stocks_count": 3,
#         "like_count": 278,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 4255,
#         "title": "Sleekoptions Daytrade",
#         "url": "http://www.sleekoptions.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3275
#         }
#       ],
#       "links": [
#         {
#           "title": "SleekOptions.com - Algo based option trading Alerts",
#           "url": "https://www.sleekoptions.com/sleekscan.aspx?sub1=dscan",
#           "shortened_url": "https://www.sleekoptions.com/sleekscan.aspx?sub1=dscan",
#           "shortened_expanded_url": "sleekoptions.com/sleekscan....",
#           "description": "SleekOptions.com - Algo based option trading alerts gives you near real time alerts of good setups for option trading. Option trading alerts are triggered by the system using proprietary algo , historical data analysis, technical analysis and price action analysis. The alerts are posted in both the website and also in chat platform for push and email notifications.",
#           "image": null,
#           "created_at": "2021-04-14T12:49:29Z",
#           "video_url": null,
#           "source": {
#             "name": "Sleekoptions",
#             "website": "https://www.sleekoptions.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 315213390,
#       "body": "Large Print $ROST Size: 201118 Price: 126.39 Time: 1600 Amount: $25,419,304.02",
#       "created_at": "2021-04-13T20:00:01Z",
#       "user": {
#         "id": 4441233,
#         "username": "TradeWithAlerts",
#         "name": "TradeWithAlerts",
#         "avatar_url": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "join_date": "2020-12-17",
# ...
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 315077868,
#       "body": "$ROST MOST RECENT TWEETS Trend/Searches/ranked 1M% Change 33 % https://t8sk.com/ROST",
#       "created_at": "2021-04-13T16:28:04Z",
#       "user": {
#         "id": 4634569,
#         "username": "Gokugod",
#         "name": "I fetch most recent tweets",
#         "avatar_url": "https://avatars.stocktwits.com/production/4634569/thumb-1615277008.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4634569/thumb-1615277008.png",
#         "join_date": "2021-01-20",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 26,
#         "following": 0,
#         "ideas": 6313,
#         "watchlist_stocks_count": 7,
#         "like_count": 17,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "$ROST - Rate Your Stocks & Cryptos | T8SK",
#           "url": "https://t8sk.com/ROST",
#           "shortened_url": "https://t8sk.com/rost/",
#           "shortened_expanded_url": "t8sk.com/rost/",
#           "description": "MOST RECENT $ROST TWEETS $ROST - BR: $121.78 -> NOW: $128.00 Ross Stores: The Upside Could Be Priced In Read more: https://seekingalpha.com/article/4417697-ross-stores-upside-be-priced-in?source=feed_all_articles $RIII CEO To Verify New Non Toxic Line Of Credit From $BAC https://askwarrenhq.blogspot.com/p/breaking-news.html $EXEL $SREpA $RCL $SPG $CERN $MULE $RARS $BIPH $ROST $OCLR $ACN $MYO $NAP MOST RECENT $ROST VIDEO TWEETS Don't get fooled by RSI divergence.",
#           "image": null,
#           "created_at": "2021-04-13T16:28:13Z",
#           "video_url": null,
#           "source": {
#             "name": "Rate Your Stocks & Cryptos | T8SK",
#             "website": "https://t8sk.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": {
#           "basic": "Bullish"
#         }
#       }
#     },
#     {
#       "id": 314731368,
#       "body": "Insider Morrow Brian R. reports selling 1,462 shares of $ROST for a total cost of $186,083.36 https://fintel.io/n/us/rost/morrow-brian?utm_source=stocktwits.com&amp;utm_medium=Referral&amp;utm_campaign=insider",
#       "created_at": "2021-04-12T21:00:25Z",
#       "user": {
#         "id": 127776,
#         "username": "risenhoover",
#         "name": "Wilton",
#         "avatar_url": "https://avatars.stocktwits.com/production/127776/thumb-1384448707.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/127776/thumb-1384448707.png",
#         "join_date": "2012-01-05",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 3420,
#         "following": 27,
#         "ideas": 565050,
#         "watchlist_stocks_count": 1,
#         "like_count": 1080,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2883,
#         "title": "Fintel.io",
#         "url": "https://fintel.io"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "links": [
#         {
#           "title": null,
#           "url": "https://fintel.io/n/us/rost/morrow-brian?utm_source=stocktwits.com&utm_medium=Referral&utm_campaign=insider",
#           "shortened_url": "https://fintel.io/n/us/rost/morrow-brian?utm_source=stocktwits.com&utm_medium=Referral&utm_campaign=insider",
#           "shortened_expanded_url": "fintel.io/n/us/rost/morrow-...",
#           "description": null,
#           "image": null,
#           "created_at": "2021-04-12T21:00:25Z",
#           "video_url": null,
#           "source": {
#             "name": "Fintel",
#             "website": "https://fintel.io"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314698441,
#       "body": "Large Print $ROST Size: 129282 Price: 128 Time: 1600 Amount: $16,548,096.00",
#       "created_at": "2021-04-12T20:00:02Z",
#       "user": {
#         "id": 4441233,
#         "username": "TradeWithAlerts",
#         "name": "TradeWithAlerts",
#         "avatar_url": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/4441233/thumb-1609900005.png",
#         "join_date": "2020-12-17",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 6888,
#         "following": 0,
#         "ideas": 155937,
#         "watchlist_stocks_count": 22,
#         "like_count": 184,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 6081,
#         "title": "TradeWithAI",
#         "url": "https://fotodesigners.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314681882,
#       "body": "$ROST institutional ownership down 0.1% from 88% to 87.9%",
#       "created_at": "2021-04-12T19:33:52Z",
#       "user": {
#         "id": 5027760,
#         "username": "CZARBETS",
#         "name": "Czar Bets",
#         "avatar_url": "https://avatars.stocktwits.com/production/5027760/thumb-1613600382.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/5027760/thumb-1613600382.png",
#         "join_date": "2021-02-14",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 1361,
#         "following": 0,
#         "ideas": 77830,
#         "watchlist_stocks_count": 7,
#         "like_count": 142,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 6353,
#         "title": "Czar Bets",
#         "url": "https://www.czarbets.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314653152,
#       "body": "Ross Stores CMO Brian R. Morrow Sells $186,083.36 in $ROST https://www.marketbeat.com/i/440325",
#       "created_at": "2021-04-12T18:44:42Z",
#       "user": {
#         "id": 1034235,
#         "username": "MarketBeatInsiderTrades",
#         "name": "MarketBeat Insider Trades",
#         "avatar_url": "https://avatars.stocktwits.com/production/1034235/thumb-1607010003.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/1034235/thumb-1607010003.png",
#         "join_date": "2017-04-20",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 3638,
#         "following": 60,
#         "ideas": 156233,
#         "watchlist_stocks_count": 0,
#         "like_count": 0,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1022,
#         "title": "Zapier",
#         "url": "https://zapier.com/"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3274
#         }
#       ],
#       "links": [
#         {
#           "title": "ROST Stock Forecast, Price & News (Ross Stores)",
#           "url": "https://www.marketbeat.com/i/440325",
#           "shortened_url": "https://www.marketbeat.com/stocks/NASDAQ/ROST/",
#           "shortened_expanded_url": "marketbeat.com/stocks/NASDA...",
#           "description": "Analyzing Ross Stores (NASDAQ:ROST) stock? View ROST's stock price, price target, dividend, earnings, financials, forecast, insider trades, news, and SEC filings at MarketBeat.",
#           "image": "https://www.marketbeat.com/logos/ross-stores-inc-logo.jpg",
#           "created_at": "2021-04-12T18:44:44Z",
#           "video_url": null,
#           "source": {
#             "name": "Marketbeat",
#             "website": "https://www.marketbeat.com"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314568549,
#       "body": "Ross Stores just filed its Statement of changes in beneficial owner http://www.conferencecalltranscripts.org/include?location=http://www.sec.gov/Archives/edgar/data/745732/000117911021004370/0001179110-21-004370-index.htm $ROST",
#       "created_at": "2021-04-12T16:14:11Z",
#       "user": {
#         "id": 210967,
#         "username": "cctranscripts",
#         "name": "Conference Call Transcripts",
#         "avatar_url": "https://avatars.stocktwits.com/production/210967/thumb-1363372333.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/210967/thumb-1363372333.png",
#         "join_date": "2013-01-30",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 6955,
#         "following": 10,
#         "ideas": 2580710,
#         "watchlist_stocks_count": 0,
#         "like_count": 765,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 1130,
#         "title": "cctranscripts",
#         "url": "http://conferencecalltranscripts.org"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "Conference Call Transcripts",
#           "url": "http://www.conferencecalltranscripts.org/include?location=http://www.sec.gov/Archives/edgar/data/745732/000117911021004370/0001179110-21-004370-index.htm",
#           "shortened_url": "http://www.conferencecalltranscripts.org/include/?location=http://www.sec.gov/Archives/edgar/data/745732/000117911021004370/0001179110-21-004370-index.htm",
#           "shortened_expanded_url": "sec.gov/Archives/edgar/data...",
#           "description": "Company Conference Call Transcripts",
#           "image": null,
#           "created_at": "2021-04-12T16:14:11Z",
#           "video_url": null,
#           "source": {
#             "name": "Conferencecalltranscripts",
#             "website": "http://www.conferencecalltranscripts.org"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314568453,
#       "body": "$ROST $186,083.36 of shares sold by Morrow Brian R. (President, CMO dd&#39;s DISCOUNTS), reported in a new form 4 filed with the SEC  https://newsfilter.io/a/8b8fdd495220814e08b4d82243edc22c",
#       "created_at": "2021-04-12T16:14:00Z",
#       "user": {
#         "id": 2762379,
#         "username": "Newsfilter",
#         "name": "@newsfilterio",
#         "avatar_url": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png",
#         "join_date": "2019-09-01",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 10907,
#         "following": 18,
#         "ideas": 911976,
#         "watchlist_stocks_count": 1,
#         "like_count": 531,
#         "plus_tier": "month",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 2269,
#         "title": "StockTwits Web",
#         "url": "https://stocktwits.com"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "4 Form - Statement of changes in beneficial ownership of securities - ROSS STORES, INC. (0000745732) (Issuer)",
#           "url": "https://newsfilter.io/a/8b8fdd495220814e08b4d82243edc22c",
#           "shortened_url": "https://newsfilter.io/a/8b8fdd495220814e08b4d82243edc22c",
#           "shortened_expanded_url": "newsfilter.io/a/8b8fdd49522...",
#           "description": "SEC FORM 4 SEC Form 4 Check this box if no longer subject to Section 16. Form 4 or Form 5 obligations may continue. See Instruction 1(b). Table I - Non-Derivative Securities Acquired, Disposed of, or Beneficially Owned 1. Title of Security (Instr. 3) 2. Transaction Date (Month/Day/Year) 2A.",
#           "image": null,
#           "created_at": "2021-04-12T16:14:01Z",
#           "video_url": null,
#           "source": {
#             "name": "Newsfilter",
#             "website": "https://newsfilter.io"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     },
#     {
#       "id": 314565789,
#       "body": "$ROST [15s. delayed] filed SEC form 4: President, CMO dd&#39;s DISCOUNTS Morrow Brian R.: \nDisposed 1,462 of Common Stock at price $127.28 on  https://s.flashalert.me/idk0WL",
#       "created_at": "2021-04-12T16:09:19Z",
#       "user": {
#         "id": 595702,
#         "username": "fla",
#         "name": "FlashAlert_me",
#         "avatar_url": "https://avatars.stocktwits.com/production/595702/thumb-1550769466.png",
#         "avatar_url_ssl": "https://avatars.stocktwits.com/production/595702/thumb-1550769466.png",
#         "join_date": "2015-09-09",
#         "official": false,
#         "identity": "User",
#         "classification": [],
#         "followers": 3540,
#         "following": 60,
#         "ideas": 1002727,
#         "watchlist_stocks_count": 1,
#         "like_count": 4,
#         "plus_tier": "",
#         "premium_room": "",
#         "trade_app": false
#       },
#       "source": {
#         "id": 4622,
#         "title": "FlashAlert",
#         "url": "https://flashalert.me/"
#       },
#       "symbols": [
#         {
#           "id": 3413,
#           "symbol": "ROST",
#           "title": "Ross Stores Inc.",
#           "aliases": [],
#           "is_following": false,
#           "watchlist_count": 3276
#         }
#       ],
#       "links": [
#         {
#           "title": "Flash Alert",
#           "url": "https://s.flashalert.me/idk0WL",
#           "shortened_url": "https://flashalert.me/?symbol=ROST&source=SEC&referer=https://stocktwits.com/&url=https://www.sec.gov/Archives/edgar/data/745732/000117911021004370/xslF345X03/edgar.xml&s3=ROST/2021-04-12/12-09-01_000000/4/8b8fdd495220814e08b4d82243edc22c/edgar.xml",
#           "shortened_expanded_url": "sec.gov/Archives/edgar/data...",
#           "description": "Real-time alerts about equities, ETFs, cryptocurrencies and more sent to any device",
#           "image": null,
#           "created_at": "2021-04-12T16:09:20Z",
#           "video_url": null,
#           "source": {
#             "name": "Flashalert",
#             "website": "https://flashalert.me"
#           }
#         }
#       ],
#       "mentioned_users": [],
#       "entities": {
#         "sentiment": null
#       }
#     }
#   ]
# }
